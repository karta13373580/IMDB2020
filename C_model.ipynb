# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
from sklearn import preprocessing
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics

# %%
data_train=pd.read_csv("C_train.csv")
data_test=pd.read_csv("y_train.csv")

# %%
data_train.shape
# Out:
# (348, 223)

# %%
min_max = MinMaxScaler()
data_train = pd.DataFrame(min_max.fit_transform(data_train), 
                                     columns=data_train.keys())

# %%
X,y=shuffle(data_train,data_test,random_state=2)
X_train,X_test,y_train,y_test=train_test_split(data_train,data_test['Input_C_013'],test_size=0.2,random_state=2)

# %%
model = Sequential()
model.add(Dense(640, activation='relu', input_dim=223))
model.add(Dense(400, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(300, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=10, activation='softmax'))
model.add(Dropout(0.1))
model.add(Dense(1))

# model = Sequential()
# model.add(Dense(384, activation='relu', input_dim=105))
# model.add(Dense(150, activation='relu'))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(units=10, activation='softmax'))
# model.add(Dropout(0.1))
# model.add(Dense(1))

# %%
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=opt, metrics=['acc'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=300, batch_size=30, verbose=1)
# Out:
# Train on 278 samples, validate on 70 samples
# Epoch 1/300
# 278/278 [==============================] - 1s 2ms/sample - loss: 0.0035 - acc: 0.0072 - val_loss: 9.2931e-06 - val_acc: 0.0143
# Epoch 2/300
# 278/278 [==============================] - 0s 355us/sample - loss: 3.1779e-04 - acc: 0.0072 - val_loss: 2.9499e-05 - val_acc: 0.0143
# Epoch 3/300
# 278/278 [==============================] - 0s 377us/sample - loss: 2.4180e-04 - acc: 0.0072 - val_loss: 1.2296e-05 - val_acc: 0.0143
# Epoch 4/300
# 278/278 [==============================] - 0s 370us/sample - loss: 1.2985e-04 - acc: 0.0072 - val_loss: 2.6178e-05 - val_acc: 0.0143
# Epoch 5/300
# 278/278 [==============================] - 0s 380us/sample - loss: 6.2662e-05 - acc: 0.0072 - val_loss: 4.0632e-06 - val_acc: 0.0143
# Epoch 6/300
# 278/278 [==============================] - 0s 380us/sample - loss: 4.0922e-05 - acc: 0.0072 - val_loss: 6.5383e-07 - val_acc: 0.0143
# Epoch 7/300
# ...

# %%
#驗證集看成功率
min_max = MinMaxScaler()
X_test = pd.DataFrame(min_max.fit_transform(X_test), 
                                     columns=X_test.keys())

v_prediction=model.predict(X_test)

print(np.sqrt(metrics.mean_squared_error(y_test, v_prediction)))
plt.plot(v_prediction)
# Out:
# 0.0008197906788953846

# %%
#測試集
test=pd.read_csv("C_test.csv")
min_max = MinMaxScaler()
test = pd.DataFrame(min_max.fit_transform(test), 
                                     columns=test.keys())

C_13_prediction=model.predict(test)
plt.plot(C_13_prediction)

# %%
C_13_prediction = pd.DataFrame(C_13_prediction)
result=pd.read_excel("result.xlsx")
result['Input_C_013']=C_13_prediction

# %%
X,y=shuffle(data_train,data_test,random_state=2)
X_train,X_test,y_train,y_test=train_test_split(data_train,data_test['Input_C_046'],test_size=0.2,random_state=2)

model = Sequential()
model.add(Dense(640, activation='relu', input_dim=223))
model.add(Dense(400, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(300, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=10, activation='softmax'))
model.add(Dropout(0.1))
model.add(Dense(1))

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=opt, metrics=['acc'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=300, batch_size=30, verbose=1)

test=pd.read_csv("C_test.csv")
min_max = MinMaxScaler()
test = pd.DataFrame(min_max.fit_transform(test), 
                                     columns=test.keys())

C_46_prediction=model.predict(test)
plt.plot(C_46_prediction)

C_46_prediction = pd.DataFrame(C_46_prediction)
result['Input_C_046']=C_46_prediction
# prediction.to_csv("prediction.csv",index=0)
# Out:
# Train on 278 samples, validate on 70 samples
# Epoch 1/300
# 278/278 [==============================] - 0s 948us/sample - loss: 0.0033 - acc: 0.0144 - val_loss: 4.6938e-04 - val_acc: 0.0143
# Epoch 2/300
# 278/278 [==============================] - 0s 176us/sample - loss: 0.0026 - acc: 0.0144 - val_loss: 3.5856e-04 - val_acc: 0.0143
# Epoch 3/300
# 278/278 [==============================] - 0s 187us/sample - loss: 0.0021 - acc: 0.0144 - val_loss: 1.4298e-04 - val_acc: 0.0143
# Epoch 4/300
# 278/278 [==============================] - 0s 187us/sample - loss: 0.0022 - acc: 0.0144 - val_loss: 8.9208e-05 - val_acc: 0.0143
# Epoch 5/300
# 278/278 [==============================] - 0s 190us/sample - loss: 0.0017 - acc: 0.0144 - val_loss: 5.5273e-05 - val_acc: 0.0143
# Epoch 6/300
# 278/278 [==============================] - 0s 193us/sample - loss: 0.0017 - acc: 0.0144 - val_loss: 8.9704e-05 - val_acc: 0.0143
# Epoch 7/300
# ...

# %%
X,y=shuffle(data_train,data_test,random_state=2)
X_train,X_test,y_train,y_test=train_test_split(data_train,data_test['Input_C_049'],test_size=0.2,random_state=2)

model = Sequential()
model.add(Dense(640, activation='relu', input_dim=223))
model.add(Dense(400, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(300, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=10, activation='softmax'))
model.add(Dropout(0.1))
model.add(Dense(1))

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=opt, metrics=['acc'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=300, batch_size=30, verbose=1)

test=pd.read_csv("C_test.csv")
min_max = MinMaxScaler()
test = pd.DataFrame(min_max.fit_transform(test), 
                                     columns=test.keys())

C_49_prediction=model.predict(test)
plt.plot(C_49_prediction)

C_49_prediction = pd.DataFrame(C_49_prediction)
result['Input_C_049']=C_49_prediction
# prediction.to_csv("prediction.csv",index=0)
# Out:
# Train on 278 samples, validate on 70 samples
# Epoch 1/300
# 278/278 [==============================] - 1s 3ms/sample - loss: 0.0026 - acc: 0.0144 - val_loss: 2.7856e-05 - val_acc: 0.0143
# Epoch 2/300
# 278/278 [==============================] - 0s 578us/sample - loss: 8.6967e-04 - acc: 0.0144 - val_loss: 3.4391e-05 - val_acc: 0.0143
# Epoch 3/300
# 278/278 [==============================] - 0s 592us/sample - loss: 8.1991e-04 - acc: 0.0144 - val_loss: 2.6419e-05 - val_acc: 0.0143
# Epoch 4/300
# 278/278 [==============================] - 0s 588us/sample - loss: 6.6767e-04 - acc: 0.0144 - val_loss: 2.8218e-05 - val_acc: 0.0143
# Epoch 5/300
# 278/278 [==============================] - 0s 570us/sample - loss: 6.2212e-04 - acc: 0.0144 - val_loss: 3.2275e-05 - val_acc: 0.0143
# Epoch 6/300
# 278/278 [==============================] - 0s 566us/sample - loss: 4.5989e-04 - acc: 0.0144 - val_loss: 2.1539e-05 - val_acc: 0.0143
# Epoch 7/300
# ...

# %%
X,y=shuffle(data_train,data_test,random_state=2)
X_train,X_test,y_train,y_test=train_test_split(data_train,data_test['Input_C_050'],test_size=0.2,random_state=2)

model = Sequential()
model.add(Dense(640, activation='relu', input_dim=223))
model.add(Dense(400, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(300, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=10, activation='softmax'))
model.add(Dropout(0.1))
model.add(Dense(1))

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=opt, metrics=['acc'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=300, batch_size=30, verbose=1)

test=pd.read_csv("C_test.csv")
min_max = MinMaxScaler()
test = pd.DataFrame(min_max.fit_transform(test), 
                                     columns=test.keys())

C_50_prediction=model.predict(test)
plt.plot(C_50_prediction)

C_50_prediction = pd.DataFrame(C_50_prediction)
result['Input_C_050']=C_50_prediction
# prediction.to_csv("prediction.csv",index=0)
# Out:
# Train on 278 samples, validate on 70 samples
# Epoch 1/300
# 278/278 [==============================] - 1s 2ms/sample - loss: 0.0053 - acc: 0.0144 - val_loss: 6.1336e-04 - val_acc: 0.0143
# Epoch 2/300
# 278/278 [==============================] - 0s 370us/sample - loss: 0.0023 - acc: 0.0144 - val_loss: 2.6640e-04 - val_acc: 0.0143
# Epoch 3/300
# 278/278 [==============================] - 0s 362us/sample - loss: 0.0016 - acc: 0.0144 - val_loss: 8.8066e-05 - val_acc: 0.0143
# Epoch 4/300
# 278/278 [==============================] - 0s 361us/sample - loss: 0.0017 - acc: 0.0144 - val_loss: 2.0913e-05 - val_acc: 0.0143
# Epoch 5/300
# 278/278 [==============================] - 0s 317us/sample - loss: 0.0015 - acc: 0.0144 - val_loss: 2.2085e-05 - val_acc: 0.0143
# Epoch 6/300
# 278/278 [==============================] - 0s 327us/sample - loss: 0.0018 - acc: 0.0144 - val_loss: 2.1243e-05 - val_acc: 0.0143
# Epoch 7/300
# ...

# %%
X,y=shuffle(data_train,data_test,random_state=2)
X_train,X_test,y_train,y_test=train_test_split(data_train,data_test['Input_C_057'],test_size=0.2,random_state=2)

model = Sequential()
model.add(Dense(640, activation='relu', input_dim=223))
model.add(Dense(400, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(300, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=10, activation='softmax'))
model.add(Dropout(0.1))
model.add(Dense(1))

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=opt, metrics=['acc'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=300, batch_size=30, verbose=1)

test=pd.read_csv("C_test.csv")
min_max = MinMaxScaler()
test = pd.DataFrame(min_max.fit_transform(test), 
                                     columns=test.keys())

C_57_prediction=model.predict(test)
plt.plot(C_57_prediction)

C_57_prediction = pd.DataFrame(C_57_prediction)
result['Input_C_057']=C_57_prediction
# prediction.to_csv("prediction.csv",index=0)
# Out:
# Train on 278 samples, validate on 70 samples
# Epoch 1/300
# 278/278 [==============================] - 0s 1ms/sample - loss: 0.0118 - acc: 0.0144 - val_loss: 2.6793e-04 - val_acc: 0.0143
# Epoch 2/300
# 278/278 [==============================] - 0s 201us/sample - loss: 0.0031 - acc: 0.0144 - val_loss: 2.2634e-04 - val_acc: 0.0143
# Epoch 3/300
# 278/278 [==============================] - 0s 212us/sample - loss: 0.0022 - acc: 0.0144 - val_loss: 1.4251e-04 - val_acc: 0.0143
# Epoch 4/300
# 278/278 [==============================] - 0s 201us/sample - loss: 0.0022 - acc: 0.0144 - val_loss: 5.9760e-05 - val_acc: 0.0143
# Epoch 5/300
# 278/278 [==============================] - 0s 201us/sample - loss: 0.0018 - acc: 0.0144 - val_loss: 1.0617e-04 - val_acc: 0.0143
# Epoch 6/300
# 278/278 [==============================] - 0s 200us/sample - loss: 0.0015 - acc: 0.0144 - val_loss: 1.8682e-04 - val_acc: 0.0143
# Epoch 7/300
# ...

# %%
X,y=shuffle(data_train,data_test,random_state=2)
X_train,X_test,y_train,y_test=train_test_split(data_train,data_test['Input_C_058'],test_size=0.2,random_state=2)

model = Sequential()
model.add(Dense(640, activation='relu', input_dim=223))
model.add(Dense(400, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(300, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=10, activation='softmax'))
model.add(Dropout(0.1))
model.add(Dense(1))

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=opt, metrics=['acc'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=300, batch_size=30, verbose=1)

test=pd.read_csv("C_test.csv")
min_max = MinMaxScaler()
test = pd.DataFrame(min_max.fit_transform(test), 
                                     columns=test.keys())

C_58_prediction=model.predict(test)
plt.plot(C_58_prediction)

C_58_prediction = pd.DataFrame(C_58_prediction)
result['Input_C_058']=C_58_prediction
# prediction.to_csv("prediction.csv",index=0)
# Out:
# Train on 278 samples, validate on 70 samples
# Epoch 1/300
# 278/278 [==============================] - 1s 5ms/sample - loss: 0.0023 - acc: 0.0144 - val_loss: 1.7590e-04 - val_acc: 0.0143
# Epoch 2/300
# 278/278 [==============================] - 0s 646us/sample - loss: 0.0016 - acc: 0.0144 - val_loss: 7.4240e-05 - val_acc: 0.0143
# Epoch 3/300
# 278/278 [==============================] - 0s 635us/sample - loss: 0.0013 - acc: 0.0144 - val_loss: 7.9598e-05 - val_acc: 0.0143
# Epoch 4/300
# 278/278 [==============================] - 0s 666us/sample - loss: 0.0014 - acc: 0.0144 - val_loss: 2.1049e-04 - val_acc: 0.0143
# Epoch 5/300
# 278/278 [==============================] - 0s 660us/sample - loss: 0.0012 - acc: 0.0144 - val_loss: 3.1636e-05 - val_acc: 0.0143
# Epoch 6/300
# 278/278 [==============================] - 0s 648us/sample - loss: 0.0014 - acc: 0.0144 - val_loss: 3.7028e-05 - val_acc: 0.0143
# Epoch 7/300
# ...

# %%
X,y=shuffle(data_train,data_test,random_state=2)
X_train,X_test,y_train,y_test=train_test_split(data_train,data_test['Input_C_096'],test_size=0.2,random_state=2)

model = Sequential()
model.add(Dense(640, activation='relu', input_dim=223))
model.add(Dense(400, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(300, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=10, activation='softmax'))
model.add(Dropout(0.1))
model.add(Dense(1))

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=opt, metrics=['acc'])
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=300, batch_size=30, verbose=1)

test=pd.read_csv("C_test.csv")
min_max = MinMaxScaler()
test = pd.DataFrame(min_max.fit_transform(test), 
                                     columns=test.keys())

C_96_prediction=model.predict(test)
plt.plot(C_96_prediction)

C_96_prediction = pd.DataFrame(C_96_prediction)
result['Input_C_096']=C_96_prediction
# prediction.to_csv("prediction.csv",index=0)
# Out:
# Train on 278 samples, validate on 70 samples
# Epoch 1/300
# 278/278 [==============================] - 1s 3ms/sample - loss: 0.0063 - acc: 0.1906 - val_loss: 3.3071e-04 - val_acc: 0.2571
# Epoch 2/300
# 278/278 [==============================] - 0s 348us/sample - loss: 0.0019 - acc: 0.1906 - val_loss: 1.2069e-04 - val_acc: 0.2571
# Epoch 3/300
# 278/278 [==============================] - 0s 337us/sample - loss: 0.0017 - acc: 0.1906 - val_loss: 1.1987e-04 - val_acc: 0.2571
# Epoch 4/300
# 278/278 [==============================] - 0s 343us/sample - loss: 0.0012 - acc: 0.1906 - val_loss: 1.0199e-04 - val_acc: 0.2571
# Epoch 5/300
# 278/278 [==============================] - 0s 347us/sample - loss: 0.0013 - acc: 0.1906 - val_loss: 2.8365e-04 - val_acc: 0.2571
# Epoch 6/300
# 278/278 [==============================] - 0s 352us/sample - loss: 0.0014 - acc: 0.1906 - val_loss: 5.8003e-05 - val_acc: 0.2571
# Epoch 7/300
# ...

# %%
result.to_excel("result.xlsx",index=0)
